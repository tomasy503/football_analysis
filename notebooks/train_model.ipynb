# %%
## Get Dataset from Roboflow

from roboflow import Roboflow

rf = Roboflow(api_key="tfOqiKJkgIqVLtFTxo9U")
project = rf.workspace("roboflow-jvuqo").project("football-players-detection-3zvbc")
version = project.version(12)
dataset = version.download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Dependency ultralytics==8.0.196 is required but found version=8.2.82, to fix: `pip install ultralytics==8.0.196`

# %%
dataset.location
# Out:
# '/Users/tomas/Documents/data_science/football_analysis/notebooks/football-players-detection-12'

# %%
# !yolo task=detect mode=train model=yolov8x.pt data={dataset.location}/data.yaml epochs=100 imgsz=1280 batch=-1 plots=True #device="mps" ##use for apple metal gpu
# Out:
# New https://pypi.org/project/ultralytics/8.2.82 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.0.196 🚀 Python-3.8.19 torch-2.2.2+cu121 CUDA:0 (NVIDIA GeForce RTX 3070, 7756MiB)
# ...

# %%
from ultralytics import YOLO

model = YOLO("runs/detect/train7/weights/best.pt")

results = model.predict("../data/raw/bmg_test.mp4", save=True)
print(results[0])
print("=====================================")
for box in results[0].boxes:
    print(box)
# Out:
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/750) /Users/tomas/Documents/data_science/football_analysis/notebooks/../data/raw/bmg_test.mp4: 736x1280 1 ball, 1 goalkeeper, 23 players, 2 referees, 984.4ms
# video 1/1 (frame 2/750) /Users/tomas/Documents/data_science/football_analysis/notebooks/../data/raw/bmg_test.mp4: 736x1280 1 ball, 1 goalkeeper, 23 players, 2 referees, 843.1ms
# ...

# %%
results = model.predict("../data/raw/bvb_test.mp4", save=True)
print(results[0])
print("=====================================")
for box in results[0].boxes:
    print(box)
# Out:
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (1/750) /home/tomas/Nextcloud/Documents/data_science/football_analysis/notebooks/../data/raw/bmg_test.mp4: 384x640 1 ball, 1 goalkeeper, 18 players, 3 referees, 25.4ms
# video 1/1 (2/750) /home/tomas/Nextcloud/Documents/data_science/football_analysis/notebooks/../data/raw/bmg_test.mp4: 384x640 1 ball, 1 goalkeeper, 18 players, 3 referees, 11.9ms
# ...
